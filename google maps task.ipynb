# %%
import googlemaps
import pandas as pd
import gmaps

# %%
#jupyter nbextension enable --py gmaps
#jupyter nbextension enable --py widgetsnbextension

# %%
43.222015,76.851250 - center Almaty
# Out:
#   File "<ipython-input-3-2710573212d7>", line 1
#     43.222015,76.851250 - center Almaty
#                                  ^
# SyntaxError: invalid syntax

# %%
df = pd.read_excel('api.xlsx')

# %%
df_new = df[0:100000]

# %%
df_new
# Out:
#               ID                                       NAME  ADDRESS_ID  \
# 0       128522.0             ПАРМАНОВА НУРБУВИ КАМЕРДИНОВНА    128464.0
# 1      3523094.0                  КСЮНИН АНТОН ВЛАДИМИРОВИЧ   3542117.0
# 2      1424855.0  ОБЪЕДИНЕН С ДРУГИМ ЛИЦЕВЫМ СЧЕТОМ  (5695)   1429005.0
# 3      4443707.0            НЕМОЛОЧНОВА СВЕТЛАНА ВАСИЛЬЕВНА   4469458.0
# 4      5505638.0                  ИВАНОВА ЛЮБОВЬ ВИКТОРОВНА   5589453.0
# ...          ...                                        ...         ...
# 99995   111025.0                     ГУСАК ТАТЬЯНА ИВАНОВНА  14915809.0
# 99996  3989506.0                КОЖКЕНОВ ЕДИЛ КАЙРБОЛАТОВИЧ  10597978.0
# 99997  5389471.0                  ПОДА ВАЛЕНТИНА СТЕПАНОВНА   5473292.0
# 99998  5404502.0                БЕГЛЯНОВ ВАСИЛИЙ ГАВРИЛОВИЧ  12884246.0
# 99999  1678152.0            МУХАМЕДЖАНОВА КУЛЯШ КАСЫМБАЕВНА  14217982.0
#
#        NAME.1               RUS_NAME  HOUSE     SUMMA
# ...

# %%
int(127.0)
# Out:
# 127

# %%
for i, j in df_new['HOUSE'].items():
    if(pd.isna(j)==True):
        print(j)

# %%
df_new['HOUSE']= df_new['HOUSE'].astype(int)
# Out:
# <ipython-input-7-b2c7e0863b3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['HOUSE']= df_new['HOUSE'].astype(int)

# %%
df_new['address'] = df_new['NAME.1']+','+df_new['RUS_NAME']+','+df_new['HOUSE'].astype(str)
# Out:
# <ipython-input-8-9a8a51b7e28f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['address'] = df_new['NAME.1']+','+df_new['RUS_NAME']+','+df_new['HOUSE'].astype(str)

# %%
df_new
# Out:
#               ID                                       NAME  ADDRESS_ID  \
# 0       128522.0             ПАРМАНОВА НУРБУВИ КАМЕРДИНОВНА    128464.0
# 1      3523094.0                  КСЮНИН АНТОН ВЛАДИМИРОВИЧ   3542117.0
# 2      1424855.0  ОБЪЕДИНЕН С ДРУГИМ ЛИЦЕВЫМ СЧЕТОМ  (5695)   1429005.0
# 3      4443707.0            НЕМОЛОЧНОВА СВЕТЛАНА ВАСИЛЬЕВНА   4469458.0
# 4      5505638.0                  ИВАНОВА ЛЮБОВЬ ВИКТОРОВНА   5589453.0
# ...          ...                                        ...         ...
# 99995   111025.0                     ГУСАК ТАТЬЯНА ИВАНОВНА  14915809.0
# 99996  3989506.0                КОЖКЕНОВ ЕДИЛ КАЙРБОЛАТОВИЧ  10597978.0
# 99997  5389471.0                  ПОДА ВАЛЕНТИНА СТЕПАНОВНА   5473292.0
# 99998  5404502.0                БЕГЛЯНОВ ВАСИЛИЙ ГАВРИЛОВИЧ  12884246.0
# 99999  1678152.0            МУХАМЕДЖАНОВА КУЛЯШ КАСЫМБАЕВНА  14217982.0
#
#        NAME.1               RUS_NAME  HOUSE     SUMMA  \
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ID          100000 non-null  float64
#  1   NAME        100000 non-null  object
#  2   ADDRESS_ID  100000 non-null  float64
#  3   NAME.1      100000 non-null  object
#  4   RUS_NAME    99942 non-null   object
#  5   HOUSE       100000 non-null  int32
#  6   SUMMA       100000 non-null  float64
#  7   address     99942 non-null   object
# dtypes: float64(3), int32(1), object(4)
# memory usage: 5.7+ MB

# %%
api_key = 'AIzaSyBeQSxPp6WG5QuWQS-L0gU_RiaWmapAwOY'

# %%
address = 'Алматы,ТОЛЕ БИ,221'#'1 Market st,San Francisco, CA'

# %%
import googlemaps
map_client = googlemaps.Client(api_key)
response2=map_client.geocode(address)
print(response2)
# Out:
# [{'address_components': [{'long_name': '221', 'short_name': '221', 'types': ['street_number']}, {'long_name': 'Tole Bi Street', 'short_name': 'Tole Bi Street', 'types': ['route']}, {'long_name': 'Almaly District', 'short_name': 'Almaly District', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Almaty', 'short_name': 'Almaty', 'types': ['locality', 'political']}, {'long_name': 'Kazakhstan', 'short_name': 'KZ', 'types': ['country', 'political']}], 'formatted_address': 'Tole Bi Street 221, Almaty, Kazakhstan', 'geometry': {'location': {'lat': 43.2508747, 'lng': 76.88195929999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 43.2522236802915, 'lng': 76.8833082802915}, 'southwest': {'lat': 43.2495257197085, 'lng': 76.88061031970848}}}, 'place_id': 'ChIJCYHtuHFpgzgR8cSubyd01mg', 'plus_code': {'compound_code': '7V2J+8Q Almaty, Kazakhstan', 'global_code': '8JMR7V2J+8Q'}, 'types': ['street_address']}]

# %%
params = { 'key':api_key, 'address':address}

# %%
import requests
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

# %%
import geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
locations=[]
for i,j in df_new['address'].items():
    if(pd.isna(j)==False):
        address = '"'+j+'"'
        data = geolocator.geocode(address)
        locations.append((data.raw.get("lat"), data.raw.get("lon")))
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-9ce7bb9192e7> in <module>
#       4         address = '"'+j+'"'
#       5         data = geolocator.geocode(address)
# ----> 6         locations.append((data.raw.get("lat"), data.raw.get("lon")))
#       7     else:
#       8         pass
#
# AttributeError: 'NoneType' object has no attribute 'raw'

# %%
location=[]
for i,j in df_new['address'].items():
    address2 = j
    params = { 'key':api_key, 'address':address2}
    response = requests.get(base_url,params = params).json()
    if response['status']=='OK':
        geometry = response['results'][0]['geometry']
        lat = geometry['location']['lat']
        lon = geometry['location']['lng']
        location.append((lat,lon))
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6a6c3b8ce730> in <module>
#       3     address2 = j
#       4     params = { 'key':api_key, 'address':address2}
# ----> 5     response = requests.get(base_url,params = params).json()
#       6     if response['status']=='OK':
#       7         geometry = response['results'][0]['geometry']
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
#location=[]
params = { 'key':api_key, 'address':df_new['address']}
response = requests.get(base_url,params = params).json()
if response['status']=='OK':
    geometry = response['results'][0]['geometry']
    lat = geometry['location']['lat']
    lon = geometry['location']['lng']
    location.append((lat,lon))

# %%
location
# Out:
# [(43.32487, 76.9081154),
#  (43.2634709, 76.90936049999999),
#  (43.2441118, 76.9497975),
#  (43.2220146, 76.8512485),
#  (43.341296, 76.91417340000001),
#  (43.2220146, 76.8512485),
#  (43.3210139, 76.9108676),
#  (43.2220146, 76.8512485),
#  (43.2220146, 76.8512485),
#  (43.2220146, 76.8512485),
#  (43.33621530000001, 76.9474453),
#  (43.341296, 76.91417340000001),
#  (43.1884943, 76.8017151),
#  (43.341296, 76.91417340000001),
#  (43.2882531, 76.9351808),
#  (43.2220146, 76.8512485),
#  (43.2220146, 76.8512485),
#  (43.2220146, 76.8512485),
#  (43.2755483, 76.8383753),
#  (43.2220146, 76.8512485),
#  (43.2806557, 76.99233),
#  (43.2755226, 76.97113689999999),
#  (43.2220146, 76.8512485),
#  (43.2295145, 76.93449369999999),
#  (43.341296, 76.91417340000001),
#  (43.2806557, 76.99233),
#  (43.2619877, 76.9297819),
#  (43.3346212, 76.9436484),
#  (43.2644349, 76.9083828),
#  (43.2220146, 76.8512485),
#  (43.2220146, 76.8512485),
#  (43.341296, 76.91417340000001),
# ...

# %%
len(location)
# Out:
# 78

# %%
import requests

response = requests.get(base_url,params = params).json()
response.keys()
# Out:
# dict_keys(['results', 'status'])

# %%
response['results']
# Out:
# [{'address_components': [{'long_name': '221',
#     'short_name': '221',
#     'types': ['street_number']},
#    {'long_name': 'Tole Bi Street',
#     'short_name': 'Tole Bi Street',
#     'types': ['route']},
#    {'long_name': 'Almaly District',
#     'short_name': 'Almaly District',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Almaty',
#     'short_name': 'Almaty',
#     'types': ['locality', 'political']},
#    {'long_name': 'Kazakhstan',
#     'short_name': 'KZ',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Tole Bi Street 221, Almaty, Kazakhstan',
#   'geometry': {'location': {'lat': 43.2508747, 'lng': 76.88195929999999},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 43.2522236802915,
#      'lng': 76.8833082802915},
#     'southwest': {'lat': 43.2495257197085, 'lng': 76.88061031970848}}},
#   'place_id': 'ChIJCYHtuHFpgzgR8cSubyd01mg',
# ...

# %%
if response['status']=='OK':
    geometry = response['results'][0]['geometry']
    lat = geometry['location']['lat']
    lon = geometry['location']['lng']
    print(lat,lon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4cedfd698e61> in <module>
# ----> 1 if response['status']=='OK':
#       2     geometry = response['results'][0]['geometry']
#       3     lat = geometry['location']['lat']
#       4     lon = geometry['location']['lng']
#       5     print(lat,lon)
#
# NameError: name 'response' is not defined

# %%
new_york_coordinates = (43.222015,76.851250)
gmaps.figure(center=new_york_coordinates, zoom_level=12)

# %%
import gmaps

gmaps.configure(api_key = 'AIzaSyBeQSxPp6WG5QuWQS-L0gU_RiaWmapAwOY')
marker_location = location#(43.2441118,76.9497975)]

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_location)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
figure_layout = {
    'width': '400px',
    'height': '400px',
    'border': '1px solid black',
    'padding': '1px'
}
locations = [(51.5, 0.1), (51.7, 0.2), (51.4, -0.2), (51.49, 0.1)]
fig = gmaps.figure(map_type = 'TERRAIN',center = new_york_coordinates, zoom_level = 12,layout = figure_layout)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='400px', padding='1px', width='400px'))

# %%
import folium
#latlong.net
m = folium.Map(locations = [46.87902,-102.789879],zoom_start=15)
folium.Marker(locations=[47.603230,-122.330260],popup = "Seatle",tooltip= "Click for more information").add_to(m)

folium.Marker().add_to(m)

# %%
# !pip install ipyleaflet
# Out:
# ...
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.5.1
#     Uninstalling ipywidgets-7.5.1:
#       Successfully uninstalled ipywidgets-7.5.1
# ...

# %%
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Out:
# Enabling notebook extension jupyter-leaflet/extension...
#       - Validating: ok

# %%
import geopandas
import geopy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1b1a05438d24> in <module>
# ----> 1 import geopandas
#       2 import geopy
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")
data = geolocator.geocode("Tolebaev St 127, Almaty 050000, Kazakhstan")
data.raw.get("lat"), data.raw.get("lon")
# Out:
# ('45.013993400000004', '78.36808107632083')
